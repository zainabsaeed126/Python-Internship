# %% [markdown]
# <a href="https://colab.research.google.com/github/zainabsaeed126/Python-Internship/blob/main/week_3_MINI_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Week 3 Mini Project
# EDA Mini-Dashboard**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = sns.load_dataset("iris")

# Show data
print(df.head())

# Chart 1: Bar Chart
average = df.groupby("species")["sepal_length"].mean()

plt.bar(average.index, average.values)
plt.title("Average Sepal Length")
plt.xlabel("Species")
plt.ylabel("Length")
plt.show()


# Chart 2: Line Chart
plt.plot(df["sepal_length"][:20])
plt.title("Sepal Length")
plt.xlabel("Sample")
plt.ylabel("Length")
plt.show()


# Chart 3: Pie Chart
species_count = df["species"].value_counts()

plt.pie(
    species_count,
    labels=species_count.index,
    autopct="%1.1f%%"
)
plt.title("Species Distribution")
plt.show()


# Chart 4: Scatter Plot
plt.scatter(df["sepal_length"], df["sepal_width"])
plt.title("Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()


# Insights
print("Insights:")
print("1. The dataset contains three different flower species.")
print("2. The average sepal length is different for each species.")
print("3. All three species have the same number of samples.")
print("4. The scatter plot shows the relationship between sepal length and sepal width.")
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Insights:
# 1. The dataset contains three different flower species.
# 2. The average sepal length is different for each species.
# 3. All three species have the same number of samples.
# 4. The scatter plot shows the relationship between sepal length and sepal width.
